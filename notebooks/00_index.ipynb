# %% [markdown]
# # Notebook Index
#
# Run notebooks in order:
#
# - [Setup & Environment](01_setup.ipynb)
# - [Data Loading & Preprocessing](02_data.ipynb)
# - [Model Definition](03_model.ipynb)
# - [Training](04_train.ipynb)
# - [Evaluation & Export](05_evaluate.ipynb)
#
# ## Environment
#
# Install dependencies via `pip install -r requirements.txt`.
